# %%
import matplotlib.pyplot as plt
import pandas as pd
import parse_raw_to_csv
import os
import numpy as np

df = pd.DataFrame()

for i in [1,2,5,8,13]:
    for f in os.listdir("../../experiments/%d_fpga" % i):
        if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"]) and not any(t in f for t in ["cpu", "pcie"]):
            df_tmp = pd.DataFrame()
            df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../../experiments/%d_fpga" % i, f), parse_raw_to_csv.parse_map.values()))
            df_tmp["beff"] = df_tmp["B/s"].sum()/21
            df_tmp["N"] = i
            df_tmp["type"] = "FPGA"
            df_tmp["n"] = df_tmp["N"] * 2
            df_tmp.loc[df_tmp["n"] == 2,"n"] = 1
            df = df.append(df_tmp)
    for f in os.listdir("../../experiments/%d_fpga" % i):
        if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"]) and "pcie" in f:
            df_tmp = pd.DataFrame()
            df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../../experiments/%d_fpga" % i, f), parse_raw_to_csv.parse_map.values()))
            df_tmp["beff"] = df_tmp["B/s"].sum()/21
            df_tmp["N"] = i
            df_tmp["type"] = "MPI + OpenCL"
            df_tmp["n"] = df_tmp["N"] * 2
            df_tmp.loc[df_tmp["n"] == 2,"n"] = 1
            df = df.append(df_tmp)
    for f in os.listdir("../../experiments/%d_fpga" % i):
        if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"]) and "cpu" in f:
            df_tmp = pd.DataFrame()
            df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../../experiments/%d_fpga" % i, f), parse_raw_to_csv.parse_map.values()))
            df_tmp["beff"] = df_tmp["B/s"].sum()/21
            df_tmp["N"] = i
            df_tmp["type"] = "MPI"
            df_tmp["n"] = df_tmp["N"] * 2
            df_tmp.loc[df_tmp["n"] == 2,"n"] = 1
            if "-n2-" in f:
                    df_tmp.loc[df_tmp["n"] == 4,"n"] = 2
            df = df.append(df_tmp)

for i in [1,2]:
    for f in os.listdir("../../experiments/%d_fpga/u280" % i):
        if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"]) and "pcie" in f:
            df_tmp = pd.DataFrame()
            df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../../experiments/%d_fpga/u280" % i, f), parse_raw_to_csv.parse_map.values()))
            df_tmp["beff"] = df_tmp["B/s"].sum()/21
            df_tmp["N"] = i
            df_tmp["type"] = "MPI + OpenCL"
            df_tmp["n"] = df_tmp["N"] * 2
            df_tmp.loc[df_tmp["n"] == 2,"n"] = 1
            df = df.append(df_tmp)

df_tmp = pd.DataFrame()
for f in os.listdir("../../experiments/1_fpga_full/u280"):
    if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"])  and "pcie" in f:
        df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../../experiments/1_fpga_full/u280", f), parse_raw_to_csv.parse_map.values()))
        df_tmp["beff"] = df_tmp["B/s"].sum()/21
df_tmp["N"] = 1
df_tmp["n"] = df_tmp["N"] * 2
df_tmp["type"] = "MPI + OpenCL"
df = df.append(df_tmp)

for i in [1,2]:
    for f in os.listdir("../../experiments/%d_fpga/u280" % i):
        if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"]) and "cpu" in f:
            df_tmp = pd.DataFrame()
            df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../../experiments/%d_fpga/u280" % i, f), parse_raw_to_csv.parse_map.values()))
            df_tmp["beff"] = df_tmp["B/s"].sum()/21
            df_tmp["N"] = i
            df_tmp["type"] = "MPI"
            df_tmp["n"] = df_tmp["N"] * 2
            df_tmp.loc[df_tmp["n"] == 2,"n"] = 1
            df = df.append(df_tmp)

df_tmp = pd.DataFrame()
for f in os.listdir("../../experiments/1_fpga_full/u280"):
    if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"])  and "cpu" in f:
        df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../../experiments/1_fpga_full/u280", f), parse_raw_to_csv.parse_map.values()))
        df_tmp["beff"] = df_tmp["B/s"].sum()/21
df_tmp["N"] = 1
df_tmp["n"] = df_tmp["N"] * 2
df_tmp["type"] = "MPI"
df = df.append(df_tmp)

df_tmp = pd.DataFrame()
for f in os.listdir("../../experiments/1_fpga_full"):
    if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"]) and not any(t in f for t in ["cpu", "pcie"]):
        df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../../experiments/1_fpga_full", f), parse_raw_to_csv.parse_map.values()))
        df_tmp["beff"] = df_tmp["B/s"].sum()/21
df_tmp["N"] = 1
df_tmp["n"] = df_tmp["N"] * 2
df_tmp["type"] = "FPGA"
df = df.append(df_tmp)

df_tmp = pd.DataFrame()
for f in os.listdir("../../experiments/1_fpga_full"):
    if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"])  and "pcie" in f:
        df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../../experiments/1_fpga_full", f), parse_raw_to_csv.parse_map.values()))
        df_tmp["beff"] = df_tmp["B/s"].sum()/21
df_tmp["N"] = 1
df_tmp["n"] = df_tmp["N"] * 2
df_tmp["type"] = "MPI + OpenCL"
df = df.append(df_tmp)

df_tmp = pd.DataFrame()
for f in os.listdir("../../experiments/1_fpga_full"):
    if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"])  and "cpu" in f:
        df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../../experiments/1_fpga_full", f), parse_raw_to_csv.parse_map.values()))
        df_tmp["beff"] = df_tmp["B/s"].sum()/21
df_tmp["N"] = 1
df_tmp["n"] = df_tmp["N"] * 2
df_tmp["type"] = "MPI"
df = df.append(df_tmp)


df["benchmark"] = df.index
df = df.apply(pd.to_numeric, errors='ignore')
df = df.reset_index()

df[(df["N"] == 1) & (df["n"] == 2)& (df["filename"].str.contains("u280"))]

# %%
import seaborn as sns

#Just use set_theme() function of seaborn library for a nice looking appearance.
sns.set_theme()

fig, beff = plt.subplots(1)

beff.scatter(df[df["type"] == "FPGA"]["n"], df[df["type"] == "FPGA"]["beff"]* 1.0e-9, marker="x", label="Nallatech 520N IEC")
beff.scatter(df[(df["type"] == "MPI + OpenCL") & (~df["filename"].str.contains("u280"))]["n"], df[(df["type"] == "MPI + OpenCL") & (~df["filename"].str.contains("u280"))]["beff"]* 1.0e-9, marker="x", label="Nallatech 520N")
beff.scatter(df[(df["type"] == "MPI + OpenCL") & (df["filename"].str.contains("u280"))]["n"], df[(df["type"] == "MPI + OpenCL") & (df["filename"].str.contains("u280"))]["beff"]* 1.0e-9, marker="x", label="Xilinx Alveo U280")
beff.scatter(df[(df["type"] == "MPI") & (~df["filename"].str.contains("-n2-")) & (~df["filename"].str.contains("u280"))]["n"], df[(df["type"] == "MPI") & (~df["filename"].str.contains("-n2-")) & (~df["filename"].str.contains("u280"))]["beff"]* 1.0e-9, marker="x", label="Noctua MPI")
beff.scatter(df[(df["type"] == "MPI") & (~df["filename"].str.contains("-n2-")) & (df["filename"].str.contains("u280"))]["n"], df[(df["type"] == "MPI") & (~df["filename"].str.contains("-n2-")) & (df["filename"].str.contains("u280"))]["beff"]* 1.0e-9, marker="x", label="XACC MPI")
beff.set_xlabel("Number of FPGAs / CPUs (n)")
beff.set_ylabel("GB/s")
#beff.set_ylim((0,200))
#beff.set_xlim((0,27))
beff.set_yscale("log")
beff.set_xscale("log")

plt.rcParams['text.usetex'] = True

v = df[(df["type"] == "FPGA") & (df["n"] == 1) & (~df["filename"].str.contains("u280"))]["beff"].unique() * 1.0e-9
beff.annotate(r"n $\cdot$ %.2f GB/s" % v, (2,40))
beff.plot(np.linspace(1,30), np.linspace(1,30) * v)

v = df[(df["type"] == "MPI + OpenCL") & (df["n"] == 4) & (~df["filename"].str.contains("u280"))]["beff"].unique()/4 * 1.0e-9
beff.annotate(r"n $\cdot$ %.2f GB/s" % v, (2,0.2))
beff.plot(np.linspace(1,30), np.linspace(1,30) * v)

v = df[(df["type"] == "MPI + OpenCL") & (df["n"] == 4) & (df["filename"].str.contains("u280"))]["beff"].unique()/4 * 1.0e-9
beff.annotate(r"n $\cdot$ %.2f GB/s" % v, (2,0.14))
beff.plot(np.linspace(1,30), np.linspace(1,30) * v)

v = (df[(df["type"] == "MPI") & (df["n"] == 4) & (~df["filename"].str.contains("u280"))]["beff"].unique()/4) * 1.0e-9
print(v)
beff.annotate(r"n $\cdot$ %.2f GB/s" % v, (2,8))
beff.plot(np.linspace(1,30), np.linspace(1,30) * v)

v = (df[(df["type"] == "MPI") & (df["n"] == 4) & (df["filename"].str.contains("u280"))]["beff"].unique()/4) * 1.0e-9
print(v)
beff.annotate(r"n $\cdot$ %.2f GB/s" % v, (2,1.5))
beff.plot(np.linspace(1,30), np.linspace(1,30) * v)

beff.set_ylim((0.1,230))
beff.set_xlim((0.9,30))

plt.rcParams['text.usetex'] = False

beff.legend(loc="lower right", bbox_to_anchor=(1,0))

fig.tight_layout()

fig.savefig("beff_effective_bw.pdf")

# %%
df[df["n"] == 2]["filename"].unique()

# %%
import matplotlib
fig, beff = plt.subplots(1, figsize=(4.5,4.5))

for i, n in enumerate(sorted(set(df["n"]))):
    color=next(beff._get_lines.prop_cycler)['color']
    beff.scatter(df[(df["n"] == n) & (df["type"] == "FPGA")]["MSize"], df[(df["n"] == n) & (df["type"] == "FPGA")]["B/s"]* 1.0e-9, label="%2d FPGAs" % n, color=color, marker="x")
    beff.plot([0,2 ** 21], [n * 20, n* 20], linestyle="--", color=color, alpha=0.7)
    if not n == 1:
        beff.annotate("%d GB/s" % (n * 20), (1,n * 20 + 3))
beff.set_xlabel("Message Size in Byte")
beff.set_ylabel("GB/s")
beff.set_ylim((1,555))
beff.set_xlim((1,2 ** 21))
beff.set_xscale("log")
beff.legend(loc="upper right", bbox_to_anchor=(1.4,1))
#beff.grid(which="major", linestyle=":", color="gray", axis="y")
beff.spines["right"].set_visible(False)
beff.spines["top"].set_visible(False)
#fig.tight_layout()
fig.savefig("beff_bw_message_sizes.pdf", bbox_inches='tight')

# %%
df_c = pd.DataFrame()

# for i in [1]:
#     for f in os.listdir("../experiments/b_eff_cyclic"):
#         if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"]) and "N%d_" % i in f and  not "mpi" in f:
#             df_tmp = pd.DataFrame()
#             df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../experiments/b_eff_cyclic", f), parse_raw_to_csv.parse_map.values()))
#             df_tmp["beff"] = df_tmp["B/s"].sum()/21
#             df_tmp["N"] = i
#             df_tmp["type"] = "MPI + OpenCL"
#             df_tmp["n"] = df_tmp["N"] * 2
#             df_c = df_c.append(df_tmp)
#     for f in os.listdir("../experiments/b_eff_cyclic"):
#         if any(f.endswith(e) for e in [".txt",".out"]) and any(f.startswith(s) for s in ["beff"]) and "N%d_" % i in f and "mpi" in f:
#             df_tmp = pd.DataFrame()
#             df_tmp = df_tmp.append(parse_raw_to_csv.parse_file_or_folder(os.path.join("../experiments/b_eff_cyclic", f), parse_raw_to_csv.parse_map.values()))
#             df_tmp["beff"] = df_tmp["B/s"].sum()/21
#             df_tmp["N"] = i
#             df_tmp["type"] = "MPI"
#             df_tmp["n"] = df_tmp["N"] * 2
#             df_c = df_c.append(df_tmp)

# df_c = df_c.apply(pd.to_numeric, errors='ignore')
# df_c = df_c.reset_index()

df_c = df

# %%
import matplotlib
fig, beff = plt.subplots(1, figsize=(4.5,4.5))


for i, n in enumerate([2]): #enumerate(sorted(set(df["n"]))):
    color=next(beff._get_lines.prop_cycler)['color']  
    beff.scatter(df_c[(df_c["n"] == n*2) & (df_c["type"] == "MPI + OpenCL") & (~df["filename"].str.contains("u280"))]["MSize"], df_c[(df_c["n"] == n*2) & (df_c["type"] == "MPI + OpenCL")& (~df["filename"].str.contains("u280"))]["B/s"]* 1.0e-9, label="Nallatech 520N", marker="x", color="C2")
    beff.scatter(df_c[(df_c["n"] == n*2) & (df_c["type"] == "MPI + OpenCL")& (df["filename"].str.contains("u280"))]["MSize"], df_c[(df_c["n"] == n*2) & (df_c["type"] == "MPI + OpenCL")& (df["filename"].str.contains("u280"))]["B/s"]* 1.0e-9, label="Xilinx Alveo U280", marker="x", color="C5")
    beff.scatter(df[(df["n"] == n) & (df["type"] == "FPGA")]["MSize"], df[(df["n"] == n) & (df["type"] == "FPGA")]["B/s"]* 1.0e-9, label="Nallatech 520N IEC", marker="x", color="C3")
    beff.scatter(df_c[(df_c["n"] == n) & (df_c["N"] == n)& (df_c["type"] == "MPI")& (~df["filename"].str.contains("u280"))]["MSize"], df_c[(df_c["N"] == n) & (df_c["n"] == n) & (df_c["type"] == "MPI")& (~df["filename"].str.contains("u280"))]["B/s"]* 1.0e-9, label="Noctua MPI" , marker="x", color="C0")  
    # beff.scatter(df_c[(df_c["n"] == n) & (df_c["N"] == 1)& (df_c["type"] == "MPI") & (df_c["filename"].str.contains("u280"))]["MSize"], df_c[(df_c["N"] == 1) & (df_c["n"] == n) & (df_c["type"] == "MPI")& (df_c["filename"].str.contains("u280"))]["B/s"]* 1.0e-9, label="Alveo MPI" , marker="x", color="C1")  
    # pcie = (2 * df_c[(df_c["n"] == n) & (df_c["N"] == n)& (df_c["type"] == "MPI")]["MSize"]/(7.8e9 * 2)).values + (df_c[(df_c["N"] == 2) & (df_c["n"] == 2) & (df_c["type"] == "MPI")]["transfer"] / df_c[(df_c["N"] == 2) & (df_c["n"] == 2) & (df_c["type"] == "MPI")]["looplength"]).values
    # r = 2 * df_c[(df_c["n"] == 2) & (df_c["N"] == 2)& (df_c["type"] == "MPI")]["MSize"] / (pcie)
    # beff.plot(df_c[(df_c["n"] == n) & (df_c["N"] == n)& (df_c["type"] == "MPI")]["MSize"], r * 1.0e-9, label="Model MPI + PCIe", linestyle=":", color="C4") 

    pcie = (2 * df_c[(df_c["n"] == n) & (df_c["N"] == n)& (df_c["type"] == "MPI") & (~df_c["filename"].str.contains("u280"))]["MSize"].values/(df_c[(df_c["n"] == 1) & (df_c["N"] == 1)& (df_c["type"] == "MPI + OpenCL") & (~df_c["filename"].str.contains("u280"))]["B/s"] * 4)).values + (df_c[(df_c["N"] == 2) & (df_c["n"] == 2) & (df_c["type"] == "MPI") & (~df_c["filename"].str.contains("u280"))]["transfer"] / df_c[(df_c["N"] == 2) & (df_c["n"] == 2) & (df_c["type"] == "MPI") & (~df_c["filename"].str.contains("u280"))]["looplength"]).values
    r = 2 * df_c[(df_c["n"] == 2) & (df_c["N"] == 2)& (df_c["type"] == "MPI") & (~df_c["filename"].str.contains("u280"))]["MSize"] / (pcie)
    #beff.plot(df_c[(df_c["n"] == n) & (df_c["N"] == n)& (df_c["type"] == "MPI")]["MSize"], r * 1.0e-9, label="Model MPI + PCIe", linestyle=":", color="C2") 

    r = 2 * 2 * df_c[(df_c["n"] == 2) & (df_c["N"] == 2)& (df_c["type"] == "MPI") & (~df_c["filename"].str.contains("u280"))]["MSize"] / np.array([np.ceil(size / 64) / 156.25e6 + 520e-9 for size in df_c[(df_c["n"] == 2) & (df_c["N"] == 2)& (df_c["type"] == "MPI") & (~df_c["filename"].str.contains("u280"))]["MSize"]])
    beff.plot(df_c[(df_c["n"] == n) & (df_c["N"] == n)& (df_c["type"] == "MPI")]["MSize"], r * 1.0e-9, label="Model IEC", linestyle=":", color="C3") 


    theomax = 1/ (2/15.6e9 + 1/25e9) * 1.0e-9
    print(theomax)
    beff.plot([0,2 ** 21], [40, 40], linestyle="--", color="black", alpha=0.7)
    beff.plot([0,2 ** 21], [ 25, 25], linestyle="--", color="black", alpha=0.7)
    beff.plot([0,2 ** 21], [ 15.6, 15.6], linestyle="--", color="black", alpha=0.7)
    #beff.plot([0,2 ** 21], [ theomax, theomax], linestyle="--", color="black", alpha=0.7)

    beff.annotate("IEC %d GB/s" % (40), (1,38))
    beff.annotate("MPI %d GB/s" % (25), (1,23))
    beff.annotate("PCIe %.1f GB/s" % (15.6), (1,13))
    #beff.annotate("MPI + PCIe %.1f GB/s" % (theomax), (1,7))
beff.set_xlabel("Message Size in Byte")
beff.set_ylabel("GB/s")
#beff.set_ylim((1,555))
beff.set_xlim((1,2 ** 21))
beff.set_xscale("log")
#beff.set_yscale("log")
beff.legend(loc="upper left", bbox_to_anchor=(1,1))
#beff.grid(which="major", linestyle=":", color="gray", axis="y")
beff.spines["right"].set_visible(False)
beff.spines["top"].set_visible(False)
#fig.tight_layout()
fig.savefig("beff_bw_message_sizes_mpi.pdf", bbox_inches='tight')

# %%
df_c[(df_c["n"] == 2) & (df_c["N"] == 2)& (df_c["type"] == "MPI")]["MSize"].values/df_c[(df_c["n"] == 1) & (df_c["N"] == 1)& (df_c["type"] == "MPI + OpenCL") & (~df_c["filename"].str.contains("u280"))]["B/s"]

# %%
def latency_model(size):
    np.ceil(size / 32) / 156.25e6 + 520e-9
